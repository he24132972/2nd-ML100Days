# %% [markdown]
# # 統計指標實作範例
# ## 常見於迴歸問題的評估指標
# * Mean Absolute Error (MAE)
# * Mean Squared Error (MSE)
#
# ## 常見於分類問題的指標
# * Binary Cross Entropy (CE)
#
# ##### 後面的課程還會有更詳細的說明

# %% [markdown]
# ## 作業1：
#
# ### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# ### Q1. 你選的這組資料為何重要
# 我所選擇的資料為:<br>
# <b>[石油管線事故, 2010-現今 (Oil Pipeline Accidents, 2010-Present)](https://www.kaggle.com/usdot/pipeline-accidents)<br></b>
# 我目前正在進行國內自來水配水管線的漏水分析,<br>
# 所以想進行類似的題目以增強我在研究上的模型建立和準確性,<br>
# 石油管線也是屬於管線的一種,<br>
# 且相對於自來水管線,<br>
# 石油管線若是發生洩漏必定對環境及經濟產生更大的影響,<br>
# 也因此我想對此組資料進行分析和預測.
#
#
# ### Q2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# kaggle上所寫的資料來源為<b>美國運輸部(United States Department of Transportation, DoT)</b>及<b>油管及有害物質安全總署(Pipeline and Hazardous Materials Safety Administration, PHMSA)</b>所提供,<br>
# 至於資料如何蒐集似乎並無特別說明.
#
# ### Q3. 蒐集而來的資料型態為何
# 資料集中有48項欄位, 包含字串, 數值, 日期三種資料型態的csv檔.
#
# ### Q4. 這組資料想解決的問題如何評估
# 因預測結果為管線的破漏與否,<br>
# 應為一介於0~1的機率值,<br>
# 因此應該以CE為指標進行評估.

# %% [markdown]
# ## 作業2：
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# ### Q1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 於「提升業績」方面,<br>
# 統計所有司機的營收入依照高低排序,<br>
# 在此假設將其分為5類: 0%~20%, 21%~40% 41%~60%, 61%~80%, 81%~100%,<br>
# 由此可得知甚麼樣的載客量, 路程, 天氣...不同資訊及可分為5類,<br>
# 再藉由分析各項因素和業績分類的關係進而提升業績.
#
# ### Q2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 於車上安裝紀錄路程、乘客資訊、氣候、費用、行車時間等等的紀錄器於車上,<br>
# 再將其輸出至電腦進行分析.
#
# ### Q3. 蒐集而來的資料型態為何
# 字串: 如乘客性別, 汽車品牌, 所在縣市...等<br>
# 數值: 如天氣, 車程, 收入...等<br>
# 日期: 行車日期, 氣候時間...等<br>
#
# ### Q4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 可以根據上述數據進行分類模型的建立,<br>
# 再新取得的資料進行餵進模型裡面進行驗證.

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_square_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

MSE = mean_square_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 272.619
